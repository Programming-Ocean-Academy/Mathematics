# %% [markdown]
# # Complete 100 Differential Equations Problem Set
#
# ## I. Basic Concepts & Slope Fields (1–10)
# 1. Identify order and degree of $$y'' + 3y' + 2y = 0$$
# 2. Sketch slope field for $$y' = x + y$$
# 3. Sketch slope field for $$y' = y(1 - y)$$
# 4. Determine if $$y = e^{-x}$$ satisfies $$y' + y = 0$$
# 5. Determine if $$y = x^2 + 1$$ satisfies $$y' = 2x$$
# 6. Plot isoclines for $$y' = x - y$$
# 7. Verify $$y = Ce^{2x}$$ is a family of solutions to $$y' = 2y$$
# 8. Verify $$y = Cx^3$$ solves $$xy' - 3y = 0$$
# 9. Find general solution to $$y' = 0$$
# 10. Find general solution to $$y' = k,$$ where \(k\) is constant
#
# ---
#
# ## II. Separable Equations (11–25)
# 11. $$y' = xy$$
# 12. $$y' = y(1 - y)$$
# 13. $$y' = x^2y^3$$
# 14. $$y' = \frac{x}{1 + y^2}$$
# 15. $$y' = \sin x \cos y$$
# 16. $$y' = e^{x + y}$$
# 17. $$y' = \frac{y}{x}$$
# 18. $$y' = (x^2 + 1)y^2$$
# 19. $$y' = \frac{2xy}{x^2 - 1}$$
# 20. $$y' = \frac{1 - y^2}{1 + x^2}$$
# 21. $$y' = y\ln y$$
# 22. $$y' = \frac{x^3}{y^2}$$
# 23. $$y' = (1 + x^2)(1 + y^2)$$
# 24. $$y' = \frac{ye^x}{x}$$
# 25. $$y' = \frac{y}{x + y}$$
#
# ---
#
# ## III. Linear First-Order Equations (26–40)
# 26. $$y' + y = e^x$$
# 27. $$y' - 2y = 0$$
# 28. $$y' + 3y = 6$$
# 29. $$y' + \frac{y}{x} = 1$$
# 30. $$y' - \frac{2y}{x} = x^2$$
# 31. $$y' + 2xy = 3x^2$$
# 32. $$y' + y\tan x = \sin x$$
# 33. $$y' + \frac{y}{x} = e^x$$
# 34. $$y' + 2y = e^{-x}$$
# 35. $$y' - 4y = 2e^{3x}$$
# 36. $$y' + y\ln x = x$$
# 37. $$y' - y\sec x = \tan x$$
# 38. $$y' + \frac{2y}{x} = \sin x$$
# 39. $$y' + y = x e^{-x}$$
# 40. $$y' + 2xy = \cos x$$
#
# ---
#
# ## IV. Exact & Integrating Factor Methods (41–50)
# 41. $$(2xy + y^2)\,dx + (x^2 + 2xy)\,dy = 0$$
# 42. $$(3x^2 + y)\,dx + (x + 2y)\,dy = 0$$
# 43. $$(y + 2x)\,dx + (x + 3y)\,dy = 0$$
# 44. $$(y^2 - 2x)\,dx + (2y - x^2)\,dy = 0$$
# 45. $$(2x + y)\,dx + (x + 2y)\,dy = 0$$
# 46. $$(y^2 + xy)\,dx + x^2\,dy = 0$$
# 47. $$(x + y)\,dx + (y - x)\,dy = 0$$
# 48. $$(2xy - y^2)\,dx + (x^2 - 2xy)\,dy = 0$$
# 49. $$(3x^2 + 2y)\,dx + (2x + 3y^2)\,dy = 0$$
# 50. $$(y + e^x)\,dx + (x + e^y)\,dy = 0$$
#
# ---
#
# ## V. Homogeneous & Bernoulli Equations (51–60)
# 51. $$y' = \frac{y}{x} + \frac{x^2}{y}$$
# 52. $$y' = \frac{x + y}{x - y}$$
# 53. $$y' = \frac{xy + y^2}{x^2}$$
# 54. $$y' = \frac{x^2 + y^2}{xy}$$
# 55. $$y' = \frac{y - x}{y + x}$$
# 56. $$y' + \frac{y}{x} = \frac{1}{x^2}$$
# 57. $$y' + \frac{y}{x} = x^2$$
# 58. $$y' + y = y^2$$
# 59. $$y' + y = y^n$$
# 60. $$y' + 3y = y^2 e^{2x}$$
#
# ---
#
# ## VI. Second-Order Linear Homogeneous (61–75)
# 61. $$y'' = 0$$
# 62. $$y'' + y = 0$$
# 63. $$y'' - y = 0$$
# 64. $$y'' + 4y' + 4y = 0$$
# 65. $$y'' + 5y' + 6y = 0$$
# 66. $$y'' - 3y' + 2y = 0$$
# 67. $$y'' + 9y = 0$$
# 68. $$y'' - 2y' + y = 0$$
# 69. $$y'' + 2y' + 5y = 0$$
# 70. $$y'' + y' - 6y = 0$$
# 71. $$y'' - 4y = 0$$
# 72. $$y'' + 16y = 0$$
# 73. $$y'' + 2y' + y = 0$$
# 74. $$y'' - 2y' + 10y = 0$$
# 75. $$y'' + 4y' + 5y = 0$$
#
# ---
#
# ## VII. Second-Order Non-Homogeneous (76–85)
# 76. $$y'' + y = \sin x$$
# 77. $$y'' + 4y = 8\sin(2x)$$
# 78. $$y'' - y = e^x$$
# 79. $$y'' + y = e^{2x}$$
# 80. $$y'' - 3y' + 2y = e^{2x}$$
# 81. $$y'' + 9y = 3\cos(3x)$$
# 82. $$y'' + 2y' + y = x$$
# 83. $$y'' - 4y = 2e^{2x}$$
# 84. $$y'' + 2y' + 10y = 5\sin(3x)$$
# 85. $$y'' - y = \cosh x$$
#
# ---
#
# ## VIII. Applications to Modeling (86–95)
# 86. Exponential growth: $$\frac{dy}{dt} = ky$$
# 87. Radioactive decay: $$\frac{dN}{dt} = -kN$$
# 88. Newton’s cooling law: $$\frac{dT}{dt} = -k(T - T_s)$$
# 89. Logistic growth: $$\frac{dP}{dt} = rP\left(1 - \frac{P}{K}\right)$$
# 90. Falling body: $$m\frac{dv}{dt} = mg - kv$$
# 91. RC circuit: $$\frac{dq}{dt} + \frac{1}{RC}q = E$$
# 92. RL circuit: $$L\frac{di}{dt} + Ri = E_0\sin(\omega t)$$
# 93. Damped spring: $$m x'' + c x' + kx = 0$$
# 94. Driven harmonic oscillator: $$x'' + \omega^2x = F_0\cos(\omega t)$$
# 95. Mixing problem: tank inflow/outflow model
#
# ---
#
# ## IX. Systems of Differential Equations (96–100)
# 96. $$x' = x + y,\quad y' = x - y$$
# 97. $$x' = 2x - y,\quad y' = x + 3y$$
# 98. $$x' = 3x + 4y,\quad y' = -4x + 3y$$
# 99. $$x' = -y,\quad y' = x$$
# 100. $$x'' + y'' = -x - y$$
