# %% [markdown]
# # Complete 100-Problem Integral List
#
# ## I. Basic Indefinite Integrals — Power Rule (1–10)
# 1. $$\int x\,dx$$
# 2. $$\int x^2\,dx$$
# 3. $$\int (3x^3 + 2x)\,dx$$
# 4. $$\int (5x^4 - 7x^2 + 4)\,dx$$
# 5. $$\int \frac{1}{x^3}\,dx$$
# 6. $$\int (x^{-2} + 3x^{-4})\,dx$$
# 7. $$\int (2x^{1/2} + 3x^{3/2})\,dx$$
# 8. $$\int (x^5 + 4x^{-1})\,dx$$
# 9. $$\int \frac{1}{\sqrt{x}}\,dx$$
# 10. $$\int (7x^3 - 9)\,dx$$
#
# ## II. Constant & Linearity Rules (11–20)
# 11. $$\int (4x^2 - 3x + 2)\,dx$$
# 12. $$\int (7 - 5x + x^2)\,dx$$
# 13. $$\int (3x - 4)\,dx$$
# 14. $$\int (2x^2 + 5)\,dx$$
# 15. $$\int (8x^3 - 6x^2 + 4x - 2)\,dx$$
# 16. $$\int (10x^4 - 3)\,dx$$
# 17. $$\int (a x^n + b)\,dx$$
# 18. $$\int (9x^{-1} + 2x^{-2})\,dx$$
# 19. $$\int \left(\frac{6}{x} + \frac{3}{x^2}\right)\,dx$$
# 20. $$\int (1 + 2x + 3x^2 + 4x^3)\,dx$$
#
# ## III. Exponential & Logarithmic Integrals (21–30)
# 21. $$\int e^x\,dx$$
# 22. $$\int e^{3x}\,dx$$
# 23. $$\int e^{2x+1}\,dx$$
# 24. $$\int 5^x\,dx$$
# 25. $$\int a^{2x}\,dx$$
# 26. $$\int \ln x\,dx$$
# 27. $$\int x\ln x\,dx$$
# 28. $$\int \frac{1}{x}\,dx$$
# 29. $$\int e^{x^2}\,dx \quad\text{(formal symbol only)}$$
# 30. $$\int e^{x}\sin x\,dx$$
#
# ## IV. Trigonometric Integrals (31–45)
# 31. $$\int \sin x\,dx$$
# 32. $$\int \cos x\,dx$$
# 33. $$\int \tan x\,dx$$
# 34. $$\int \cot x\,dx$$
# 35. $$\int \sec x\,dx$$
# 36. $$\int \csc x\,dx$$
# 37. $$\int \sin(3x)\,dx$$
# 38. $$\int \cos(5x)\,dx$$
# 39. $$\int x\sin x\,dx$$
# 40. $$\int x\cos x\,dx$$
# 41. $$\int \sin^2 x\,dx$$
# 42. $$\int \cos^2 x\,dx$$
# 43. $$\int \sin x \cos x\,dx$$
# 44. $$\int \tan^2 x\,dx$$
# 45. $$\int \sec^2 x\,dx$$
#
# ## V. Inverse Trigonometric & Special Forms (46–55)
# 46. $$\int \frac{1}{1+x^2}\,dx$$
# 47. $$\int \frac{1}{\sqrt{1-x^2}}\,dx$$
# 48. $$\int \frac{1}{x\sqrt{x^2-1}}\,dx$$
# 49. $$\int \frac{x}{\sqrt{1-x^2}}\,dx$$
# 50. $$\int \frac{1}{a^2+x^2}\,dx$$
# 51. $$\int \frac{1}{\sqrt{x^2-a^2}}\,dx$$
# 52. $$\int \frac{x}{x^2+a^2}\,dx$$
# 53. $$\int \frac{x^2}{\sqrt{1+x^2}}\,dx$$
# 54. $$\int \frac{dx}{x^2+4}$$
# 55. $$\int \frac{dx}{x^2-9}$$
#
# ## VI. Substitution Method (56–70)
# 56. $$\int (2x)(x^2+1)^5\,dx$$
# 57. $$\int (3x^2)(x^3+1)^4\,dx$$
# 58. $$\int \cos(2x)\,dx$$
# 59. $$\int \sin(4x+1)\,dx$$
# 60. $$\int e^{2x+3}\,dx$$
# 61. $$\int \frac{2x}{x^2+4}\,dx$$
# 62. $$\int \frac{3x^2}{(x^3+2)^5}\,dx$$
# 63. $$\int \frac{x}{\sqrt{x^2+1}}\,dx$$
# 64. $$\int \frac{2x}{(x^2+1)^2}\,dx$$
# 65. $$\int \frac{1}{(3x+1)^2}\,dx$$
# 66. $$\int \cos(5x+2)\,dx$$
# 67. $$\int \sin^3(2x)\cos(2x)\,dx$$
# 68. $$\int e^{x^2}\,2x\,dx$$
# 69. $$\int (x^2+1)e^{x^3+3x}\,dx$$
# 70. $$\int \frac{\sin(3x)}{\cos^2(3x)}\,dx$$
#
# ## VII. Integration by Parts (71–80)
# 71. $$\int x e^x\,dx$$
# 72. $$\int x \cos x\,dx$$
# 73. $$\int x \sin x\,dx$$
# 74. $$\int x \ln x\,dx$$
# 75. $$\int x^2 e^x\,dx$$
# 76. $$\int e^x \sin x\,dx$$
# 77. $$\int e^x \cos x\,dx$$
# 78. $$\int x e^{2x}\,dx$$
# 79. $$\int x^3 \sin(2x)\,dx$$
# 80. $$\int x^2 \ln x\,dx$$
#
# ## VIII. Partial Fractions (81–90)
# 81. $$\int \frac{1}{x(x-1)}\,dx$$
# 82. $$\int \frac{1}{(x+1)(x+2)}\,dx$$
# 83. $$\int \frac{3x+5}{x^2+4x+3}\,dx$$
# 84. $$\int \frac{1}{(x-1)^2(x+2)}\,dx$$
# 85. $$\int \frac{2x+1}{x^2+1}\,dx$$
# 86. $$\int \frac{x^2+3x+2}{x(x+1)}\,dx$$
# 87. $$\int \frac{x^2}{x^3+1}\,dx$$
# 88. $$\int \frac{1}{x^2(x-1)}\,dx$$
# 89. $$\int \frac{3x-1}{x^2-4}\,dx$$
# 90. $$\int \frac{x+2}{x^2+x}\,dx$$
#
# ## IX. Trig Substitution & Advanced Forms (91–95)
# 91. $$\int \frac{dx}{\sqrt{a^2-x^2}}$$
# 92. $$\int \frac{dx}{x\sqrt{x^2-1}}$$
# 93. $$\int \sqrt{a^2-x^2}\,dx$$
# 94. $$\int \frac{x^2}{\sqrt{x^2+4}}\,dx$$
# 95. $$\int \frac{x^3}{(x^2+1)^{3/2}}\,dx$$
#
# ## X. Definite Integrals & Applications (96–100)
# 96. $$\int_{0}^{2} (3x^2+1)\,dx$$
# 97. $$\int_{1}^{3} (x^3-2x)\,dx$$
# 98. $$\int_{0}^{\pi} \sin x\,dx$$
# 99. $$\int_{0}^{\pi/2} \cos^2 x\,dx$$
# 100. $$\text{Find the area under } y=x^2 \text{ from } x=0 \text{ to } x=3.$$
